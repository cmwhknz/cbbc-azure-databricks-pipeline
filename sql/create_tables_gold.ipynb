# %% [markdown]
# # Cbbc Stake Distribution

# %%
# %sql
CREATE TABLE IF NOT EXISTS gold.cbbc_stake_distribution (
    trade_date DATE,
    call_level_range BIGINT,
    total_net_cash_flow_within DOUBLE,
    bull_bear STRING
)
USING DELTA;
